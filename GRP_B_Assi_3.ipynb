# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
file= pd.read_csv("Airquality1.csv")
file
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0             1   41.0    190.0   7.4    67      5    1     High
# 1             2   36.0    118.0   8.0    72      5    2   Medium
# 2             3   12.0    149.0  12.6    74      5    3      Low
# 3             4   18.0    313.0  11.5    62      5    4     High
# 4             5    NaN      NaN  14.3    56      5    5      Low
# ..          ...    ...      ...   ...   ...    ...  ...      ...
# 148         149   30.0    193.0   6.9    70      9   26   Medium
# 149         150    NaN    145.0  13.2    77      9   27      Low
# 150         151   14.0    191.0  14.3    75      9   28     High
# 151         152   18.0    131.0   8.0    76      9   29     High
# 152         153   20.0    223.0  11.5    68      9   30      Low
#
# [153 rows x 8 columns]

# %%
file["Ozone"]= file["Ozone"].fillna(file["Ozone"].mean())
file["Solar.R"]= file["Solar.R"].fillna(file["Solar.R"].mean())

# %%
file
# Out:
#      Unnamed: 0     Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0             1  41.00000  190.000000   7.4    67      5    1     High
# 1             2  36.00000  118.000000   8.0    72      5    2   Medium
# 2             3  12.00000  149.000000  12.6    74      5    3      Low
# 3             4  18.00000  313.000000  11.5    62      5    4     High
# 4             5  42.12931  185.931507  14.3    56      5    5      Low
# ..          ...       ...         ...   ...   ...    ...  ...      ...
# 148         149  30.00000  193.000000   6.9    70      9   26   Medium
# 149         150  42.12931  145.000000  13.2    77      9   27      Low
# 150         151  14.00000  191.000000  14.3    75      9   28     High
# 151         152  18.00000  131.000000   8.0    76      9   29     High
# 152         153  20.00000  223.000000  11.5    68      9   30      Low
#
# [153 rows x 8 columns]

# %%
file.drop('Unnamed: 0',axis=1,inplace=True)

# %%
file
# Out:
#         Ozone     Solar.R  Wind  Temp  Month  Day Humidity
# 0    41.00000  190.000000   7.4    67      5    1     High
# 1    36.00000  118.000000   8.0    72      5    2   Medium
# 2    12.00000  149.000000  12.6    74      5    3      Low
# 3    18.00000  313.000000  11.5    62      5    4     High
# 4    42.12931  185.931507  14.3    56      5    5      Low
# ..        ...         ...   ...   ...    ...  ...      ...
# 148  30.00000  193.000000   6.9    70      9   26   Medium
# 149  42.12931  145.000000  13.2    77      9   27      Low
# 150  14.00000  191.000000  14.3    75      9   28     High
# 151  18.00000  131.000000   8.0    76      9   29     High
# 152  20.00000  223.000000  11.5    68      9   30      Low
#
# [153 rows x 7 columns]

# %%
plt.pie
# Out:
# <function matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None)>

# %%
labels=['Ozone','Solar.R','Wind','Temp']

# %%
file.columns
# Out:
# Index(['Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day', 'Humidity'], dtype='object')

# %%
sizes=[file['Ozone'].mean(),file['Solar.R'].mean(),file['Wind'].mean(),file['Temp'].mean()]

# %%
colors=['red','green','pink','yellow']

# %%
explode=(0.1,0,0,0)

# %%
plt.pie(sizes,explode=explode,labeldistance=1.1,labels=labels,
colors=colors,autopct='%0.1f%%')
plt.title('Average Data')
plt.show()

# %%
def addlabels():
 for i in range(len(file.iloc[0:21,3])):
  plt.text(i,file.iloc[0:21,3][i],file.iloc[0:21,3][i],ha='center')
    
y=np.arange(len(file.iloc[0:21,3]))
plt.figure(figsize=(10,6))
addlabels()
plt.bar(x=y,height=file.iloc[0:21,3],tick_label=y,color="dodgerblue")
plt.title('Wind measure for 1st-20th May')
plt.xlabel('Days')
plt.ylabel('Wind')
plt.show()

# %%
 file.boxplot(column=['Ozone','Wind','Temp','Solar.R'],grid=True)
plt.title('Box-Plot')
plt.suptitle('Temperature')
plt.ylabel('range')
plt.savefig('plot3.png')

# %%
plt.figure(figsize=(10,6))
plt.hist(x=file['Temp'],bins=20,color="Red",label="Temp")
plt.title("Temperature count")
plt.xlabel("Temperature")
plt.ylabel("count")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10,6))
plt.scatter(file.iloc[0:30,5],file.iloc[0:30,3],color="green")
plt.title("Wind measures of May month")
plt.xlabel("Day")
plt.ylabel("Wind")
# Out:
# Text(0, 0.5, 'Wind')

# %%
seaborn.heatmap(data=file.iloc[0:30,[0,1,2,3]])
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(file.iloc[0:30,5],file.iloc[0:30,3],color="blue")
plt.title('Temperature of May month')
plt.xlabel("Day")
plt.ylabel('Temperature')
# Out:
# Text(0, 0.5, 'Temperature')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
text=open("sample.txt").read()
word_cloud=WordCloud(background_color="white",height=2225,width=4450).generate(text)
plt.imshow(word_cloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from wordcloud import WordCloud,STOPWORDS
#       3 text=open("sample.txt").read()
#       4 word_cloud=WordCloud(background_color="white",height=2225,width=4450).generate(text)
#
# ModuleNotFoundError: No module named 'wordcloud'
