# %%
import pandas as pd
import numpy as np

# %%
ob=pd.read_csv(r'C:\Users\hp\Downloads\dataset_Facebook1.csv')

# %%
ob
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
ob.shape
# Out:
# (500, 19)

# %%
ob.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
ob.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
sub1_row=ob.iloc[:200,:4]

# %%
sub1_row
# Out:
#      Page total likes    Type  Category  Post Month
# 0              139441   Photo         2          12
# 1              139441  Status         2          12
# 2              139441   Photo         3          12
# 3              139441   Photo         2          12
# 4              139441   Photo         2          12
# ..                ...     ...       ...         ...
# 195            133594   Photo         2           8
# 196            133594   Photo         1           8
# 197            133594   Photo         2           8
# 198            133451   Photo         1           8
# 199            132817   Photo         3           8
#
# [200 rows x 4 columns]

# %%
sub1_row.shape
# Out:
# (200, 4)

# %%
sub2_row=ob.iloc[200:300,3:6]

# %%
sub2_row
# Out:
#      Post Month  Post Weekday  Post Hour
# 200           8             4          3
# 201           8             3          9
# 202           8             3          2
# 203           8             2         10
# 204           8             2          3
# ..          ...           ...        ...
# 295           6             2          2
# 296           6             1         14
# 297           6             1          3
# 298           6             7         11
# 299           6             7          4
#
# [100 rows x 3 columns]

# %%
sub2_row.shape
# Out:
# (100, 3)

# %%
sub3_col=ob.iloc[:,:3]

# %%
sub3_col
# Out:
#      Page total likes    Type  Category
# 0              139441   Photo         2
# 1              139441  Status         2
# 2              139441   Photo         3
# 3              139441   Photo         2
# 4              139441   Photo         2
# ..                ...     ...       ...
# 495             85093   Photo         3
# 496             81370   Photo         2
# 497             81370   Photo         1
# 498             81370   Photo         3
# 499             81370   Photo         2
#
# [500 rows x 3 columns]

# %%
sub4_col=ob.iloc[:,2:6]

# %%
sub4_col
# Out:
#      Category  Post Month  Post Weekday  Post Hour
# 0           2          12             4          3
# 1           2          12             3         10
# 2           3          12             3          3
# 3           2          12             2         10
# 4           2          12             2          3
# ..        ...         ...           ...        ...
# 495         3           1             7          2
# 496         2           1             5          8
# 497         1           1             5          2
# 498         3           1             4         11
# 499         2           1             4          4
#
# [500 rows x 4 columns]

# %%
sub4_col.shape
# Out:
# (500, 4)

# %%
merge_row=pd.concat([sub1_row,sub2_row])
merge_row
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441.0   Photo       2.0          12           NaN        NaN
# 1            139441.0  Status       2.0          12           NaN        NaN
# 2            139441.0   Photo       3.0          12           NaN        NaN
# 3            139441.0   Photo       2.0          12           NaN        NaN
# 4            139441.0   Photo       2.0          12           NaN        NaN
# ..                ...     ...       ...         ...           ...        ...
# 295               NaN     NaN       NaN           6           2.0        2.0
# 296               NaN     NaN       NaN           6           1.0       14.0
# 297               NaN     NaN       NaN           6           1.0        3.0
# 298               NaN     NaN       NaN           6           7.0       11.0
# 299               NaN     NaN       NaN           6           7.0        4.0
#
# [300 rows x 6 columns]

# %%
merge_col=pd.merge(sub3_col,sub4_col,left_index= True ,right_index= True)

# %%
merge_col
# Out:
#      Page total likes    Type  Category_x  Category_y  Post Month  \
# 0              139441   Photo           2           2          12
# 1              139441  Status           2           2          12
# 2              139441   Photo           3           3          12
# 3              139441   Photo           2           2          12
# 4              139441   Photo           2           2          12
# ..                ...     ...         ...         ...         ...
# 495             85093   Photo           3           3           1
# 496             81370   Photo           2           2           1
# 497             81370   Photo           1           1           1
# 498             81370   Photo           3           3           1
# 499             81370   Photo           2           2           1
#
#      Post Weekday  Post Hour
# 0               4          3
# 1               3         10
# 2               3          3
# 3               2         10
# ...

# %%
merge_col.shape
# Out:
# (500, 7)

# %%
ob.sort_values(by="Category")
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
ob.sort_values(by="Category" ,ascending= False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 108            136736  Photo         3          10             7          9
# 322            123047  Photo         3           6             2          5
# 331            119198  Photo         3           5             3          5
# 330            120050  Photo         3           5             3         12
# 329            120050  Photo         3           5             4          4
# ..                ...    ...       ...         ...           ...        ...
# 111            136736  Photo         1          10             6          8
# 110            136736  Photo         1          10             6         10
# 339            117764  Photo         1           5             4         10
# 105            137020  Photo         1          10             2          4
# 250            129600  Photo         1           7             7          6
#
# ...

# %%
trans=ob.transpose()
trans
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
ob.melt(id_vars=["Type"],value_vars=["Category","Post Month","Post Weekday","Paid"])
# Out:
#         Type  variable  value
# 0      Photo  Category    2.0
# 1     Status  Category    2.0
# 2      Photo  Category    3.0
# 3      Photo  Category    2.0
# 4      Photo  Category    2.0
# ...      ...       ...    ...
# 1995   Photo      Paid    0.0
# 1996   Photo      Paid    0.0
# 1997   Photo      Paid    0.0
# 1998   Photo      Paid    0.0
# 1999   Photo      Paid    NaN
#
# [2000 rows x 3 columns]
