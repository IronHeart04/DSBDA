# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"Airquality1.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  153 non-null    int64
#  1   Ozone       116 non-null    float64
#  2   Solar.R     146 non-null    float64
#  3   Wind        153 non-null    float64
#  4   Temp        153 non-null    int64
#  5   Month       153 non-null    int64
#  6   Day         153 non-null    int64
#  7   Humidity    145 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 9.7+ KB

# %%
data=data.drop("Unnamed: 0",axis=1)
data
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day Humidity
# 0     41.0    190.0   7.4    67      5    1     High
# 1     36.0    118.0   8.0    72      5    2   Medium
# 2     12.0    149.0  12.6    74      5    3      Low
# 3     18.0    313.0  11.5    62      5    4     High
# 4      NaN      NaN  14.3    56      5    5      Low
# ..     ...      ...   ...   ...    ...  ...      ...
# 148   30.0    193.0   6.9    70      9   26   Medium
# 149    NaN    145.0  13.2    77      9   27      Low
# 150   14.0    191.0  14.3    75      9   28     High
# 151   18.0    131.0   8.0    76      9   29     High
# 152   20.0    223.0  11.5    68      9   30      Low
#
# [153 rows x 7 columns]

# %%
data['Ozone']=data['Ozone'].fillna(data['Ozone'].mean())
data['Solar.R']=data['Solar.R'].fillna(data['Solar.R'].mean())

# %%
data['Humidity']=data['Humidity'].fillna(data['Humidity'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Ozone       0
# Solar.R     0
# Wind        0
# Temp        0
# Month       0
# Day         0
# Humidity    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
data['Humidity']=label.fit_transform(data['Humidity'])
data['Humidity'].unique()
# Out:
# array([0, 2, 1])

# %%
data['Humidity']
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      1
#       ..
# 148    2
# 149    1
# 150    0
# 151    0
# 152    1
# Name: Humidity, Length: 153, dtype: int32

# %%
plt.scatter(x = data["Wind"],y = data["Temp"])
plt.title("Wind Scatter plot")
plt.xlabel("Wind")
plt.ylabel("Temperature")
plt.show()

# %%
sns.pairplot(data)

# %%
corr = data.corr()
sns.heatmap(corr,annot = True)
plt.title("Correlation Heatmap Of Airquality Data")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap Of Airquality Data')

# %%
sns.barplot(x=data["Month"],y=data["Temp"]).set(title="Month vs Temperature")
# Out:
# [Text(0.5, 1.0, 'Month vs Temperature')]

# %%
h = data.iloc[1:21, 2]
v = data.iloc[1:21, 3]
plt.plot(h, label="Wind", marker="o", linestyle="dotted")
plt.plot(v, label="Temp", marker="o", linestyle="dashed")
plt.title("Line graph for Wind and Temp")
plt.ylabel("Value Range")
plt.xlabel("Days")
plt.legend()

# %%
sns.boxplot(x=data["Month"],y=data["Temp"])
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Temp'>

# %%
h=data.iloc[:,0]
plt.hist(h,bins='auto')
plt.title('Histogram ')
plt.xlabel("Ozone")
# Out:
# Text(0.5, 0, 'Ozone')

# %%
import matplotlib.pyplot as plt
labels='Ozone','Solar.R','Wind',"Temperature"
sizes=[data['Ozone'].mean(),data["Solar.R"].mean(),data['Wind'].mean(),data["Temp"].mean()]
colors=['red','cyan','green','yellow']
plt.pie(sizes,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True,startangle=14)
plt.title("Aairquality Factors")
# Out:
# Text(0.5, 1.0, 'Aairquality Factors')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
text=open("sample.txt").read()
word_cloud=WordCloud(background_color="white",height=2225,width=4450).generate(text)
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
text
# Out:
# 'What is Big Data?\nBig Data is a collection of data that is huge in volume, yet growing exponentially with time. It is a data with so large size and complexity that none of traditional data management tools can store it or process it efficiently. Big data is also a data but with huge size. \n\nTypes Of Big Data\nFollowing are the types of Big Data:\n\nStructured\nUnstructured\nSemi-structured\n\nStructured\nAny data that can be stored, accessed and processed in the form of fixed format is termed as a â€˜structuredâ€™ data. \n\nUnstructured\nAny data with unknown form or the structure is classified as unstructured data. \n\nSemi-structured\nSemi-structured data can contain both the forms of data. We can see semi-structured data as a structured in form but it is actually not defined with e.g. a table definition in relational DBMS.\nCharacteristics Of Big Data\nBig data can be described by the following characteristics:\n1.\tVolume\n2.\tVariety\n3.\tVelocity\n4.\tVariability\n(i) Volum
# ...
